# %%
library(gprofiler2)
library(dplyr)
library(ggplot2)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
run_gprofiler <- function(file_name) {
    path <- '../data/depGeneID_2_6_0.2_no_abs_FINAL/'
    genes = read.table(paste0(path, file_name), header = TRUE, sep = "\t", stringsAsFactors = FALSE)$CycID
    gostres <- gost(query = genes, 
                organism = "mmusculus", ordered_query = FALSE, 
                multi_query = FALSE, significant = TRUE, exclude_iea = FALSE, 
                measure_underrepresentation = FALSE, evcodes = FALSE, 
                user_threshold = 0.05, correction_method = "g_SCS", 
                domain_scope = "annotated", custom_bg = NULL, 
                numeric_ns = "", sources = NULL, as_short_link = FALSE, highlight = TRUE)
    gostres$result$ratio <- gostres$result$intersection_size / gostres$result$query_size
    return (gostres)
}

# %%
hdac3 <- run_gprofiler('hdac3_dep_geneID.txt')
nr1d1 <- run_gprofiler('nr1d1_dep_geneID.txt')
nfil3 <- run_gprofiler('nfil3_dep_geneID.txt')

nr1d1$result$group <- 'NR1D1'
hdac3$result$group <- 'HDAC3'
nfil3$result$group <- 'NFIL3'

combined <- rbind(nr1d1$result, hdac3$result, nfil3$result)
combined$group <- factor(combined$group, levels = c('NR1D1', 'HDAC3', 'NFIL3'))

# %%
#print out which databases are used
unique(combined$source)
# Out:
#  [1] "CORUM" "GO:BP" "GO:CC" "GO:MF" "HP"    "KEGG"  "REAC"  "TF"    "MIRNA"
# [10] "WP"

# %%
combined_KEGG = combined[combined$source == 'KEGG',]

# %%
library(ggplot2)

ggplot(combined_KEGG, aes(x = group, y = interaction(term_name), 
                          color = -log10(p_value), size = ratio)) +
  geom_point() +
  scale_color_gradient(low = "blue", high = "red") +
  scale_size(range = c(1, 5), 
             breaks = c(0.02, 0.1, 0.2),  # Customize these values based on your data
             labels = c("0.02", "0.1", "0.2")) +  # Fix typo in labels
  labs(y = "KEGG Terms", 
       color = "-Log10(p-value)", size = "Gene Ratio") +
  theme_minimal() +
  theme(axis.text.y = element_text(size = 8),   # Adjust y-axis label size
        axis.text.x = element_text(size = 10, angle = 45, hjust = 1)) +  # Adjust x-axis label size and angle
  ggtitle("Dependent Genes Comparative KEGG Plot")
# Out:
# plot without title

# %%
combined_TF <- combined[combined$source == 'TF',]

# Filter rows where term_id does not contain an underscore - remove redundant rows
combined_TF <- combined_TF %>% filter(!grepl("_", term_id))
combined_TF$term_name_short <- sub("Factor: ","",combined_TF$term_name)

combined_TF_top10 <- rbind(combined_TF[combined_TF$group == 'NR1D1',] %>% head(10),
                           combined_TF[combined_TF$group == 'HDAC3',] %>% head(10),
                           combined_TF[combined_TF$group == 'NFIL3',] %>% head(10)
                           )

# %%
ggplot(combined_TF_top10, aes(x = group, y = interaction(term_name_short), 
                          color = -log10(p_value), size = ratio)) +
  geom_point() +
  scale_color_gradient(low = "blue", high = "red") +
  scale_size(range = c(1, 5), 
             breaks = c(0.5, 0.75, 0.8),  # Customize these values based on your data
             labels = c("0.5", "0.75", "0.8")) +  # Fix typo in labels
  labs(y = "Transcription Factor Binding Sites", 
       color = "-Log10(p-value)", size = "Gene Ratio") +
  theme_minimal() +
  theme(axis.text.y = element_text(size = 8),   # Adjust y-axis label size
        axis.text.x = element_text(size = 10, angle = 45, hjust = 1)) +  # Adjust x-axis label size and angle
  ggtitle("Dependent Genes Enriched Motif Plot")
# Out:
# plot without title

# %% [markdown]
# # run same analysis on unique genes

# %%
hdac3 <- run_gprofiler('hdac3_uniq_ID.txt')
nr1d1 <- run_gprofiler('nr1d1_uniq_ID.txt')
nfil3 <- run_gprofiler('nfil3_uniq_ID.txt')

nr1d1$result$group <- 'NR1D1'
hdac3$result$group <- 'HDAC3'
nfil3$result$group <- 'NFIL3'

combined_uniq <- rbind(nr1d1$result, hdac3$result, nfil3$result)
combined_uniq$group <- factor(combined_uniq$group, levels = c('NR1D1', 'HDAC3', 'NFIL3'))

# %%
combined_KEGG = combined_uniq[combined_uniq$source == 'KEGG',]

# %%
library(ggplot2)

ggplot(combined_KEGG, aes(x = group, y = interaction(term_name), 
                          color = -log10(p_value), size = ratio)) +
  geom_point() +
  scale_color_gradient(low = "blue", high = "red") +
  scale_size(range = c(1, 5), 
             breaks = c(0.02, 0.1, 0.2),  # Customize these values based on your data
             labels = c("0.02", "0.1", "0.2")) +  # Fix typo in labels
  labs(y = "GO Terms", 
       color = "-Log10(p-value)", size = "Gene Ratio") +
  theme_minimal() +
  theme(axis.text.y = element_text(size = 8),   # Adjust y-axis label size
        axis.text.x = element_text(size = 10, angle = 45, hjust = 1)) +  # Adjust x-axis label size and angle
  ggtitle("Unique Genes Comparative KEGG Plot")
# Out:
# plot without title

# %%
combined_TF
# Out:
#     query   significant p_value      term_size query_size intersection_size
# 1   query_1 TRUE        5.051889e-28 14398     670        576
# 2   query_1 TRUE        6.155264e-27 14823     670        584
# 3   query_1 TRUE        7.267789e-25 15957     670        606
# 4   query_1 TRUE        1.707328e-24 14210     670        564
# 5   query_1 TRUE        9.710312e-23 13469     670        541
# 6   query_1 TRUE        3.917252e-20 10412     670        448
# 7   query_1 TRUE        1.127826e-18 16194     670        599
# 8   query_1 TRUE        1.771061e-14 11263     670        456
# 9   query_1 TRUE        1.603327e-13  7897     670        348
# 10  query_1 TRUE        1.881663e-13  9726     670        406
# 11  query_1 TRUE        5.424915e-13 14647     670        546
# 12  query_1 TRUE        1.482046e-12  8125     670        352
# 13  query_1 TRUE        1.210007e-11 13371     670        507
# 14  query_1 TRUE        7.881866e-11 11968     670        464
# 15  query_1 TRUE        1.477865e-10 10528     670        420
# 16  query_1 TRUE        1.720143e-10  9499     670        388
# 17  query_1 TRUE        2.193309e-10 13635     670        510
# 18  query_1 TRUE        2.301160e-10  9933     670        401
# 19  query_1 TRUE        3.329805e-10  8618     670        359
# 20  query_1 TRUE        1.079664e-09 14449     670        530
# 21  query_1 TRUE        1.824601e-09 15146     670        548
# 22  query_1 TRUE        2.182941e-09  8941     670        366
# 23  query_1 TRUE        1.094286e-08  9128     670        369
# 24  query_1 TRUE        1.166196e-08  9802     670        390
# 25  query_1 TRUE        1.758579e-08  8746     670        356
# 26  query_1 TRUE        3.573806e-08 10715     670        416
# 27  query_1 TRUE        3.881220e-08  9013     670        363
# 28  query_1 TRUE        5.929884e-08  6974     670        296
# 29  query_1 TRUE        9.117014e-08  6313     670        273
# 30  query_1 TRUE        9.465864e-08  8067     670        331
# ... ...     ...         ...          ...       ...        ...
# 253 query_1 TRUE        2.601167e-02  4691     500        148
# 254 query_1 TRUE        3.011249e-02  7634     500        221
# 255 query_1 TRUE        3.080592e-02  8386     500        239
# 256 query_1 TRUE        3.388132e-02  7111     500        208
# 257 query_1 TRUE        3.518067e-02  7816     500        225
# 258 query_1 TRUE        3.746634e-02  6147     500        184
# 259 query_1 TRUE        3.910493e-02  6962     500        204
# 260 query_1 TRUE        4.176464e-02  5006     500        155
# 261 query_1 TRUE        4.276751e-02  7176     500        209
# 262 query_1 TRUE        4.335138e-02  4004     500        129
# 263 query_1 TRUE        4.513203e-02  4623     500        145
# 264 query_1 TRUE        4.811541e-02  2348     500         84
# 265 query_1 TRUE        9.938863e-06 14823     313        259
# 266 query_1 TRUE        7.772206e-05 15957     313        270
# 267 query_1 TRUE        1.548403e-04  8659     313        171
# 268 query_1 TRUE        3.269513e-04 16194     313        271
# 269 query_1 TRUE        5.031083e-04  9128     313        176
# 270 query_1 TRUE        1.813983e-03  8941     313        171
# 271 query_1 TRUE        2.649564e-03 13635     313        236
# 272 query_1 TRUE        3.749099e-03  6414     313        131
# 273 query_1 TRUE        4.109483e-03 11263     313        203
# 274 query_1 TRUE        4.164577e-03  9656     313        180
# 275 query_1 TRUE        4.913042e-03  8794     313        167
# 276 query_1 TRUE        6.990673e-03  7319     313        144
# 277 query_1 TRUE        8.597942e-03 14398     313        244
# 278 query_1 TRUE        8.859562e-03  7089     313        140
# 279 query_1 TRUE        9.700421e-03  4192     313         93
# 280 query_1 TRUE        2.785964e-02  7232     313        140
# 281 query_1 TRUE        3.700597e-02 14210     313        239
# 282 query_1 TRUE        4.357177e-02  5199     313        107
#     precision recall     term_id   source
# 1   0.8597015 0.04000556 TF:M00333 TF
# 2   0.8716418 0.03939823 TF:M00716 TF
# 3   0.9044776 0.03797706 TF:M04662 TF
# 4   0.8417910 0.03969036 TF:M10209 TF
# 5   0.8074627 0.04016631 TF:M10276 TF
# 6   0.6686567 0.04302728 TF:M00803 TF
# 7   0.8940299 0.03698901 TF:M01240 TF
# 8   0.6805970 0.04048655 TF:M02089 TF
# 9   0.5194030 0.04406737 TF:M00428 TF
# 10  0.6059701 0.04174378 TF:M12470 TF
# 11  0.8149254 0.03727726 TF:M01981 TF
# 12  0.5253731 0.04332308 TF:M01783 TF
# 13  0.7567164 0.03791788 TF:M02874 TF
# 14  0.6925373 0.03877005 TF:M00144 TF
# 15  0.6268657 0.03989362 TF:M07380 TF
# 16  0.5791045 0.04084640 TF:M02933 TF
# 17  0.7611940 0.03740374 TF:M02844 TF
# 18  0.5985075 0.04037048 TF:M01991 TF
# 19  0.5358209 0.04165700 TF:M02913 TF
# 20  0.7910448 0.03668074 TF:M02872 TF
# 21  0.8179104 0.03618117 TF:M07991 TF
# 22  0.5462687 0.04093502 TF:M00932 TF
# 23  0.5507463 0.04042507 TF:M07395 TF
# 24  0.5820896 0.03978780 TF:M00025 TF
# 25  0.5313433 0.04070432 TF:M07980 TF
# 26  0.6208955 0.03882408 TF:M01660 TF
# 27  0.5417910 0.04027516 TF:M07250 TF
# 28  0.4417910 0.04244336 TF:M10211 TF
# 29  0.4074627 0.04324410 TF:M08005 TF
# 30  0.4940299 0.04103136 TF:M00981 TF
# ... ...       ...        ...       ...
# 253 0.2960000 0.03154978 TF:M10363 TF
# 254 0.4420000 0.02894944 TF:M01977 TF
# 255 0.4780000 0.02849988 TF:M01986 TF
# 256 0.4160000 0.02925046 TF:M00915 TF
# 257 0.4500000 0.02878710 TF:M02820 TF
# 258 0.3680000 0.02993330 TF:M02039 TF
# 259 0.4080000 0.02930192 TF:M00430 TF
# 260 0.3100000 0.03096284 TF:M00244 TF
# 261 0.4180000 0.02912486 TF:M01979 TF
# 262 0.2580000 0.03221778 TF:M00976 TF
# 263 0.2900000 0.03136491 TF:M08905 TF
# 264 0.1680000 0.03577513 TF:M01273 TF
# 265 0.8274760 0.01747285 TF:M00716 TF
# 266 0.8626198 0.01692047 TF:M04662 TF
# 267 0.5463259 0.01974824 TF:M00931 TF
# 268 0.8658147 0.01673459 TF:M01240 TF
# 269 0.5623003 0.01928133 TF:M07395 TF
# 270 0.5463259 0.01912538 TF:M00932 TF
# 271 0.7539936 0.01730840 TF:M02844 TF
# 272 0.4185304 0.02042407 TF:M03567 TF
# 273 0.6485623 0.01802362 TF:M02089 TF
# 274 0.5750799 0.01864126 TF:M00733 TF
# 275 0.5335463 0.01899022 TF:M00196 TF
# 276 0.4600639 0.01967482 TF:M10278 TF
# 277 0.7795527 0.01694680 TF:M00333 TF
# 278 0.4472843 0.01974891 TF:M03807 TF
# 279 0.2971246 0.02218511 TF:M02773 TF
# 280 0.4472843 0.01935841 TF:M08867 TF
# 281 0.7635783 0.01681914 TF:M10209 TF
# 282 0.3418530 0.02058088 TF:M09681 TF
#     term_name                                          effective_domain_size
# 1   Factor: ZF5; motif: NRNGNGCGCGCWN                  21629
# 2   Factor: ZF5; motif: GSGCGCGR                       21629
# 3   Factor: FOXN4; motif: NNWANNCGWMCGCGTCNNNNMT       21629
# 4   Factor: E2F-1; motif: GNGGGCGGGRMN                 21629
# 5   Factor: Kaiso; motif: SARNYCTCGCGAGAN              21629
# 6   Factor: E2F; motif: GGCGSG                         21629
# 7   Factor: BEN; motif: CAGCGRNV                       21629
# 8   Factor: E2F-3; motif: GGCGGGN                      21629
# 9   Factor: E2F-1; motif: NKTSSCGC                     21629
# 10  Factor: Foxn1; motif: RGAMGC                       21629
# 11  Factor: ELK-1; motif: ACCGGAWRTN                   21629
# 12  Factor: SP2; motif: GGGCGGGAC                      21629
# 13  Factor: IRF6; motif: NNNACTCYCGGKNNN               21629
# 14  Factor: Pax-5; motif: RRMSWGANWYCTNRAGCGKRACSRYNSM 21629
# 15  Factor: E2F-4; motif: NTTTCSCGCC                   21629
# 16  Factor: ZF5; motif: GYCGCGCARNGCNN                 21629
# 17  Factor: BCL6B; motif: NNNNCCGCCCCWNNNN             21629
# 18  Factor: PEA3; motif: RCCGGAAGYN                    21629
# 19  Factor: SP100; motif: NNCGTCGNNTAAWNN              21629
# 20  Factor: IRF4; motif: NNNAYTCTCGGWNNN               21629
# 21  Factor: Hes1; motif: NNCACGYGNN                    21629
# 22  Factor: Sp1; motif: NNGGGGCGGGGNN                  21629
# 23  Factor: Sp1; motif: NGGGGCGGGGN                    21629
# 24  Factor: Elk-1; motif: NNNNCCGGAARTNN               21629
# 25  Factor: Atf-1; motif: RTGACGTA                     21629
# 26  Factor: GABP-alpha; motif: CTTCCK                  21629
# 27  Factor: E2F-1; motif: NNNSSCGCSAANN                21629
# 28  Factor: E2F-4; motif: NGGGGGCGGGRMNN               21629
# 29  Factor: Tcfl5; motif: NNCNCGNGNN                   21629
# 30  Factor: CREB,; motif: NTGACGTNA                    21629
# ... ...                                                ...
# 253 Factor: DRRS; motif: GNNGGGWGGG                    21629
# 254 Factor: ESE-1; motif: NSMGGAARYN                   21629
# 255 Factor: c-ets-1; motif: ACCGGAWRYN                 21629
# 256 Factor: AP-2; motif: SNNNCCNCAGGCN                 21629
# 257 Factor: Tcfap2b; motif: NYGCCYNARGGCAN             21629
# 258 Factor: GABPalpha; motif: ACCGGAARYN               21629
# 259 Factor: E2F-1; motif: NTTSGCGG                     21629
# 260 Factor: NGFI-C; motif: WTGCGTGGGYGG                21629
# 261 Factor: ELF4; motif: CCCGGAARTN                    21629
# 262 Factor: AhR,; motif: NRCGTGNGN                     21629
# 263 Factor: TIEG1; motif: GGSGGKGNNN                   21629
# 264 Factor: SP4; motif: SCCCCGCCCCS                    21629
# 265 Factor: ZF5; motif: GSGCGCGR                       21629
# 266 Factor: FOXN4; motif: NNWANNCGWMCGCGTCNNNNMT       21629
# 267 Factor: Sp1; motif: GGGGCGGGGC                     21629
# 268 Factor: BEN; motif: CAGCGRNV                       21629
# 269 Factor: Sp1; motif: NGGGGCGGGGN                    21629
# 270 Factor: Sp1; motif: NNGGGGCGGGGNN                  21629
# 271 Factor: BCL6B; motif: NNNNCCGCCCCWNNNN             21629
# 272 Factor: Sp2; motif: NYSGCCCCGCCCCCY                21629
# 273 Factor: E2F-3; motif: GGCGGGN                      21629
# 274 Factor: SMAD4; motif: GKSRKKCAGMCANCY              21629
# 275 Factor: Sp1; motif: NGGGGGCGGGGYN                  21629
# 276 Factor: KLF3; motif: NNNNNNGGGCGGGGCNNGN           21629
# 277 Factor: ZF5; motif: NRNGNGCGCGCWN                  21629
# 278 Factor: SP2; motif: GNNGGGGGCGGGGSN                21629
# 279 Factor: Klf7; motif: NNNRCCMCGCCCNNNN              21629
# 280 Factor: AP2; motif: GCCYGSGGSN                     21629
# 281 Factor: E2F-1; motif: GNGGGCGGGRMN                 21629
# 282 Factor: ctcf; motif: YGGCCASYAGGGGGCGCYNN          21629
#     source_order parents   highlighted ratio     group
# 1   3922         TF:M00000 FALSE       0.8597015 NR1D1
# 2   3920         TF:M00000 FALSE       0.8716418 NR1D1
# 3   1174         TF:M00000 FALSE       0.9044776 NR1D1
# 4    742         TF:M00000 FALSE       0.8417910 NR1D1
# 5   3886         TF:M00000 FALSE       0.8074627 NR1D1
# 6    788         TF:M00000 FALSE       0.6686567 NR1D1
# 7    284         TF:M00000 FALSE       0.8940299 NR1D1
# 8    766         TF:M00000 FALSE       0.6805970 NR1D1
# 9    744         TF:M00000 FALSE       0.5194030 NR1D1
# 10  1172         TF:M00000 FALSE       0.6059701 NR1D1
# 11   926         TF:M00000 FALSE       0.8149254 NR1D1
# 12  3320         TF:M00000 FALSE       0.5253731 NR1D1
# 13  1798         TF:M00000 FALSE       0.7567164 NR1D1
# 14  2688         TF:M00000 FALSE       0.6925373 NR1D1
# 15   774         TF:M00000 FALSE       0.6268657 NR1D1
# 16  3934         TF:M00000 FALSE       0.5791045 NR1D1
# 17   268         TF:M00000 FALSE       0.7611940 NR1D1
# 18  2722         TF:M00000 FALSE       0.5985075 NR1D1
# 19  3300         TF:M00000 FALSE       0.5358209 NR1D1
# 20  1780         TF:M00000 FALSE       0.7910448 NR1D1
# 21  1462         TF:M00000 FALSE       0.8179104 NR1D1
# 22  3314         TF:M00000 FALSE       0.5462687 NR1D1
# 23  3312         TF:M00000 FALSE       0.5507463 NR1D1
# 24   920         TF:M00000 FALSE       0.5820896 NR1D1
# 25   192         TF:M00000 FALSE       0.5313433 NR1D1
# 26  1252         TF:M00000 FALSE       0.6208955 NR1D1
# 27   750         TF:M00000 FALSE       0.5417910 NR1D1
# 28   772         TF:M00000 FALSE       0.4417910 NR1D1
# 29  3678         TF:M00000 FALSE       0.4074627 NR1D1
# 30   566         TF:M00000 FALSE       0.4940299 NR1D1
# ... ...          ...       ...         ...       ...
# 253  722         TF:M00000 FALSE       0.2960000 HDAC3
# 254 1002         TF:M00000 FALSE       0.4420000 HDAC3
# 255  460         TF:M00000 FALSE       0.4780000 HDAC3
# 256  120         TF:M00000 FALSE       0.4160000 HDAC3
# 257 3664         TF:M00000 FALSE       0.4500000 HDAC3
# 258 1248         TF:M00000 FALSE       0.3680000 HDAC3
# 259  748         TF:M00000 FALSE       0.4080000 HDAC3
# 260 2408         TF:M00000 FALSE       0.3100000 HDAC3
# 261  906         TF:M00000 FALSE       0.4180000 HDAC3
# 262   10         TF:M00000 FALSE       0.2580000 HDAC3
# 263 3746         TF:M00000 FALSE       0.2900000 HDAC3
# 264 3338         TF:M00000 FALSE       0.1680000 HDAC3
# 265 3920         TF:M00000 FALSE       0.8274760 NFIL3
# 266 1174         TF:M00000 FALSE       0.8626198 NFIL3
# 267 3318         TF:M00000 FALSE       0.5463259 NFIL3
# 268  284         TF:M00000 FALSE       0.8658147 NFIL3
# 269 3312         TF:M00000 FALSE       0.5623003 NFIL3
# 270 3314         TF:M00000 FALSE       0.5463259 NFIL3
# 271  268         TF:M00000 FALSE       0.7539936 NFIL3
# 272 3322         TF:M00000 FALSE       0.4185304 NFIL3
# 273  766         TF:M00000 FALSE       0.6485623 NFIL3
# 274 3146         TF:M00000 FALSE       0.5750799 NFIL3
# 275 3316         TF:M00000 FALSE       0.5335463 NFIL3
# 276 1868         TF:M00000 FALSE       0.4600639 NFIL3
# 277 3922         TF:M00000 FALSE       0.7795527 NFIL3
# 278 3324         TF:M00000 FALSE       0.4472843 NFIL3
# 279 1874         TF:M00000 FALSE       0.2971246 NFIL3
# 280  116         TF:M00000 FALSE       0.4472843 NFIL3
# 281  742         TF:M00000 FALSE       0.7635783 NFIL3
# 282  622         TF:M00000 FALSE       0.3418530 NFIL3
#     term_name_short
# 1   ZF5; motif: NRNGNGCGCGCWN
# 2   ZF5; motif: GSGCGCGR
# 3   FOXN4; motif: NNWANNCGWMCGCGTCNNNNMT
# 4   E2F-1; motif: GNGGGCGGGRMN
# 5   Kaiso; motif: SARNYCTCGCGAGAN
# 6   E2F; motif: GGCGSG
# 7   BEN; motif: CAGCGRNV
# 8   E2F-3; motif: GGCGGGN
# 9   E2F-1; motif: NKTSSCGC
# 10  Foxn1; motif: RGAMGC
# 11  ELK-1; motif: ACCGGAWRTN
# 12  SP2; motif: GGGCGGGAC
# 13  IRF6; motif: NNNACTCYCGGKNNN
# 14  Pax-5; motif: RRMSWGANWYCTNRAGCGKRACSRYNSM
# 15  E2F-4; motif: NTTTCSCGCC
# 16  ZF5; motif: GYCGCGCARNGCNN
# 17  BCL6B; motif: NNNNCCGCCCCWNNNN
# 18  PEA3; motif: RCCGGAAGYN
# 19  SP100; motif: NNCGTCGNNTAAWNN
# 20  IRF4; motif: NNNAYTCTCGGWNNN
# 21  Hes1; motif: NNCACGYGNN
# 22  Sp1; motif: NNGGGGCGGGGNN
# 23  Sp1; motif: NGGGGCGGGGN
# 24  Elk-1; motif: NNNNCCGGAARTNN
# 25  Atf-1; motif: RTGACGTA
# 26  GABP-alpha; motif: CTTCCK
# 27  E2F-1; motif: NNNSSCGCSAANN
# 28  E2F-4; motif: NGGGGGCGGGRMNN
# 29  Tcfl5; motif: NNCNCGNGNN
# 30  CREB,; motif: NTGACGTNA
# ... ...
# 253 DRRS; motif: GNNGGGWGGG
# 254 ESE-1; motif: NSMGGAARYN
# 255 c-ets-1; motif: ACCGGAWRYN
# 256 AP-2; motif: SNNNCCNCAGGCN
# 257 Tcfap2b; motif: NYGCCYNARGGCAN
# 258 GABPalpha; motif: ACCGGAARYN
# 259 E2F-1; motif: NTTSGCGG
# 260 NGFI-C; motif: WTGCGTGGGYGG
# 261 ELF4; motif: CCCGGAARTN
# 262 AhR,; motif: NRCGTGNGN
# 263 TIEG1; motif: GGSGGKGNNN
# 264 SP4; motif: SCCCCGCCCCS
# 265 ZF5; motif: GSGCGCGR
# 266 FOXN4; motif: NNWANNCGWMCGCGTCNNNNMT
# 267 Sp1; motif: GGGGCGGGGC
# 268 BEN; motif: CAGCGRNV
# 269 Sp1; motif: NGGGGCGGGGN
# 270 Sp1; motif: NNGGGGCGGGGNN
# 271 BCL6B; motif: NNNNCCGCCCCWNNNN
# 272 Sp2; motif: NYSGCCCCGCCCCCY
# 273 E2F-3; motif: GGCGGGN
# 274 SMAD4; motif: GKSRKKCAGMCANCY
# 275 Sp1; motif: NGGGGGCGGGGYN
# 276 KLF3; motif: NNNNNNGGGCGGGGCNNGN
# 277 ZF5; motif: NRNGNGCGCGCWN
# 278 SP2; motif: GNNGGGGGCGGGGSN
# 279 Klf7; motif: NNNRCCMCGCCCNNNN
# 280 AP2; motif: GCCYGSGGSN
# 281 E2F-1; motif: GNGGGCGGGRMN
# 282 ctcf; motif: YGGCCASYAGGGGGCGCYNN

# %%
combined_TF <- combined_uniq[combined_uniq$source == 'TF',]

# Filter rows where term_id does not contain an underscore - remove redundant rows
combined_TF <- combined_TF %>% filter(!grepl("_", term_id))
combined_TF$term_name_short <- sub("Factor: ","",combined_TF$term_name)

combined_TF_top10 <- rbind(combined_TF[combined_TF$group == 'NR1D1',] %>% head(10),
                           combined_TF[combined_TF$group == 'HDAC3',] %>% head(10),
                           combined_TF[combined_TF$group == 'NFIL3',] %>% head(10)
                           )

# %%
ggplot(combined_TF_top10, aes(x = group, y = interaction(term_name_short), 
                          color = -log10(p_value), size = ratio)) +
  geom_point() +
  scale_color_gradient(low = "blue", high = "red") +
  scale_size(range = c(1, 5), 
             breaks = c(0.5, 0.75, 0.8),  # Customize these values based on your data
             labels = c("0.5", "0.75", "0.8")) +  # Fix typo in labels
  labs(y = "Transcription Factor Binding Sites", 
       color = "-Log10(p-value)", size = "Gene Ratio") +
  theme_minimal() +
  theme(axis.text.y = element_text(size = 8),   # Adjust y-axis label size
        axis.text.x = element_text(size = 10, angle = 45, hjust = 1)) +  # Adjust x-axis label size and angle
  ggtitle("Unique Genes Enriched Motif Plot")
# Out:
# plot without title
